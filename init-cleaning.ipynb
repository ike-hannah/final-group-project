# %%
import pandas as pd
import os

# %%
data_to_load = "Resources/spreadspoke_scores.csv"
games_df = pd.read_csv(data_to_load)

# %%
games_df.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0      9/2/1966             1966             1             False
# 1      9/3/1966             1966             1             False
# 2      9/4/1966             1966             1             False
# 3      9/9/1966             1966             2             False
# 4     9/10/1966             1966             1             False
#
#             team_home  score_home  score_away        team_away  \
# 0      Miami Dolphins        14.0        23.0  Oakland Raiders
# 1      Houston Oilers        45.0         7.0   Denver Broncos
# 2  San Diego Chargers        27.0         7.0    Buffalo Bills
# 3      Miami Dolphins        14.0        19.0    New York Jets
# 4   Green Bay Packers        24.0         3.0  Baltimore Colts
#
#   team_favorite_id  spread_favorite over_under_line         stadium  \
# 0              NaN              NaN             NaN     Orange Bowl
# 1              NaN              NaN             NaN    Rice Stadium
# 2              NaN              NaN             NaN  Balboa Stadium
# 3              NaN              NaN             NaN     Orange Bowl
# 4              NaN              NaN             NaN   Lambeau Field
#
#    stadium_neutral  weather_temperature  weather_wind_mph  weather_humidity  \
# 0            False                 83.0               6.0              71.0
# 1            False                 81.0               7.0              70.0
# 2            False                 70.0               7.0              82.0
# 3            False                 82.0              11.0              78.0
# 4            False                 64.0               8.0              62.0
#
#   weather_detail
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
games_df = games_df.dropna(subset=['team_favorite_id', 'spread_favorite', 'over_under_line'], how='all')

# %%
games_df.head(10)
# Out:
#      schedule_date  schedule_season schedule_week  schedule_playoff  \
# 538      1/12/1969             1968     Superbowl              True
# 727      1/11/1970             1969     Superbowl              True
# 2267     1/15/1978             1977     Superbowl              True
# 2500     1/21/1979             1978     Superbowl              True
# 2508      9/2/1979             1979             1             False
# 2511      9/2/1979             1979             1             False
# 2519      9/9/1979             1979             2             False
# 2534     9/16/1979             1979             3             False
# 2537     9/16/1979             1979             3             False
# 2540     9/16/1979             1979             3             False
#
#                team_home  score_home  score_away            team_away  \
# 538      Baltimore Colts         7.0        16.0        New York Jets
# 727   Kansas City Chiefs        23.0         7.0    Minnesota Vikings
# 2267      Dallas Cowboys        27.0        10.0       Denver Broncos
# 2500      Dallas Cowboys        31.0        35.0  Pittsburgh Steelers
# 2508  New Orleans Saints        34.0        40.0      Atlanta Falcons
# 2511    Seattle Seahawks        16.0        33.0   San Diego Chargers
# 2519       Detroit Lions        24.0        27.0  Washington Redskins
# 2534      Houston Oilers        20.0         6.0   Kansas City Chiefs
# 2537  New Orleans Saints        14.0        26.0  Philadelphia Eagles
# 2540    Seattle Seahawks        27.0        10.0      Oakland Raiders
#
#      team_favorite_id  spread_favorite over_under_line              stadium  \
# 538               IND            -18.0              40          Orange Bowl
# 727               MIN            -12.0              39       Tulane Stadium
# 2267              DAL             -6.0              39  Louisiana Superdome
# 2500              PIT             -3.5              37          Orange Bowl
# 2508               NO             -5.0              32  Louisiana Superdome
# 2511              SEA             -2.0            42.5     Seattle Kingdome
# 2519             PICK              0.0            35.5   Pontiac Silverdome
# 2534              TEN             -5.0              37    Houston Astrodome
# 2537               NO             -3.0              42  Louisiana Superdome
# 2540              SEA             -3.0              44     Seattle Kingdome
#
#       stadium_neutral  weather_temperature  weather_wind_mph  \
# 538              True                 66.0              12.0
# 727              True                 55.0              14.0
# 2267             True                 72.0               0.0
# 2500             True                 71.0              18.0
# 2508            False                 72.0               0.0
# 2511            False                 72.0               0.0
# 2519            False                 72.0               0.0
# 2534            False                 72.0               0.0
# 2537            False                 72.0               0.0
# 2540            False                 72.0               0.0
#
#       weather_humidity weather_detail
# 538               80.0           Rain
# 727               84.0           Rain
# 2267               NaN           DOME
# 2500              84.0           Rain
# 2508               NaN           DOME
# 2511               NaN           DOME
# 2519               NaN           DOME
# 2534               NaN           DOME
# 2537               NaN           DOME
# 2540               NaN           DOME

# %%
games_df.to_csv('gamesdata.csv', index=False)
