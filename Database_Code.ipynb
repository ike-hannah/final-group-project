# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv("https://raw.githubusercontent.com/ike-hannah/final-group-project/main/gamesdata.csv")
df
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0         1/15/1967             1966     Superbowl              True
# 1         1/14/1968             1967     Superbowl              True
# 2         1/12/1969             1968     Superbowl              True
# 3         1/11/1970             1969     Superbowl              True
# 4         1/17/1971             1970     Superbowl              True
# ...             ...              ...           ...               ...
# 10748     1/23/2022             2021      Division              True
# 10749     1/23/2022             2021      Division              True
# 10750     1/30/2022             2021    Conference              True
# 10751     1/30/2022             2021    Conference              True
# 10752     2/13/2022             2021     Superbowl              True
#
#                   team_home  score_home  score_away            team_away  \
# ...

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/ike-hannah/final-group-project/main/spreadspoke_scores.csv")
df2
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0          9/2/1966             1966             1             False
# 1          9/3/1966             1966             1             False
# 2          9/4/1966             1966             1             False
# 3          9/9/1966             1966             2             False
# 4         9/10/1966             1966             1             False
# ...             ...              ...           ...               ...
# 13227     1/23/2022             2021      Division              True
# 13228     1/23/2022             2021      Division              True
# 13229     1/30/2022             2021    Conference              True
# 13230     1/30/2022             2021    Conference              True
# 13231     2/13/2022             2021     Superbowl              True
#
#                   team_home  score_home  score_away            team_away  \
# ...

# %%
engine = create_engine("postgresql://postgres:Lexington47@localhost:5432/NFL_db")
df.to_sql("gameday", con=engine)
# Out:
# 753

# %%
engine = create_engine("postgresql://postgres:Lexington47@localhost:5432/NFL_db")
df2.to_sql("spreadspoke", con=engine)
# Out:
# 232
